# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Sample data: weight (kg) vs height (cm)
data = {
    'Weight': [45, 50, 55,  , 65, 70, 75, 80],
    'Height': [140, 145, 150, 155, 160, 165, 170, 175]
}

df = pd.DataFrame(data)

# %%
X = df[['Weight']]  # Must be 2D for sklearn
y = df['Height']    # 1D target variable

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print(f"Intercept (β₀): {model.intercept_:.2f}")
print(f"Coefficient (β₁): {model.coef_[0]:.2f}")
# Out:
# Intercept (β₀): 95.00
# Coefficient (β₁): 1.00

# %%
y_pred = model.predict(X)

# %%
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# MSE: 0.00
# RMSE: 0.00
# R² Score: 1.00

# %%
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
plt.title('Linear Regression: Height vs Weight')
plt.legend()
plt.grid(True)
plt.show()
